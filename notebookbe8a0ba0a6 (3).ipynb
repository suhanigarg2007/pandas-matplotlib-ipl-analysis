# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ipl-complete-dataset-20082020/matches.csv
# /kaggle/input/ipl-complete-dataset-20082020/deliveries.csv
# /kaggle/input/ipl-matches-analysis/__results__.html
# /kaggle/input/ipl-matches-analysis/__resultx__.html
# /kaggle/input/ipl-matches-analysis/__notebook__.ipynb
# /kaggle/input/ipl-matches-analysis/__output__.json
# /kaggle/input/ipl-matches-analysis/custom.css
# /kaggle/input/ipl-matches-analysis/__results___files/__results___20_1.png
# /kaggle/input/ipl-matches-analysis/__results___files/__results___10_0.png
# /kaggle/input/ipl-matches-analysis/__results___files/__results___13_1.png
# /kaggle/input/ipl-matches-analysis/__results___files/__results___8_1.png

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/kaggle/input/ipl-complete-dataset-20082020/matches.csv')

# %%
data
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %% [markdown]
# **Tabular data in pandas is called "Dataframe"**

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **To see the preview of top 5 rows in dataframe use head(by default)**

# %%
data.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# **To see the preview of bottom 5 rows in dataframe use tail(by default)**

# %%
data.head(2)
# first two rows
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
data.tail(2)
# last two rows
# Out:
#            id season     city        date   match_type player_of_match  \
# 1093  1426311   2024  Chennai  2024-05-24  Qualifier 2   Shahbaz Ahmed
# 1094  1426312   2024  Chennai  2024-05-26        Final        MA Starc
#
#                                          venue                team1  \
# 1093  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
# 1094  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
#
#                       team2          toss_winner toss_decision  \
# 1093       Rajasthan Royals     Rajasthan Royals         field
# 1094  Kolkata Knight Riders  Sunrisers Hyderabad           bat
#
#                      winner   result  result_margin  target_runs  \
# 1093    Sunrisers Hyderabad     runs           36.0        176.0
# 1094  Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over method        umpire1      umpire2
# 1093          20.0          N    NaN    Nitin Menon    VK Sharma
# ...

# %%
data.shape
# Out:
# (1095, 20)

# %%
data.shape[0]
# Out:
# 1095

# %%
data.shape[1]
# Out:
# 20

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
data.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
data['winner']
# to fetch a column from dataframe
# Out:
# 0             Kolkata Knight Riders
# 1               Chennai Super Kings
# 2                  Delhi Daredevils
# 3       Royal Challengers Bangalore
# 4             Kolkata Knight Riders
#                    ...
# 1090            Sunrisers Hyderabad
# 1091          Kolkata Knight Riders
# 1092               Rajasthan Royals
# 1093            Sunrisers Hyderabad
# 1094          Kolkata Knight Riders
# Name: winner, Length: 1095, dtype: object

# %%
data['winner'].shape
# Out:
# (1095,)

# %% [markdown]
# **single col or row of a dataframe is called series**

# %%
type(data['winner'])
# Out:
# pandas.core.series.Series

# %%
data[['winner','team1','team2']]
# Out:
#                            winner                        team1  \
# 0           Kolkata Knight Riders  Royal Challengers Bangalore
# 1             Chennai Super Kings              Kings XI Punjab
# 2                Delhi Daredevils             Delhi Daredevils
# 3     Royal Challengers Bangalore               Mumbai Indians
# 4           Kolkata Knight Riders        Kolkata Knight Riders
# ...                           ...                          ...
# 1090          Sunrisers Hyderabad                 Punjab Kings
# 1091        Kolkata Knight Riders          Sunrisers Hyderabad
# 1092             Rajasthan Royals  Royal Challengers Bengaluru
# 1093          Sunrisers Hyderabad          Sunrisers Hyderabad
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad
#
#                             team2
# 0           Kolkata Knight Riders
# 1             Chennai Super Kings
# 2                Rajasthan Royals
# 3     Royal Challengers Bangalore
# ...

# %%
data[['winner','team1','team2']].shape
# Out:
# (1095, 3)

# %%
type(data[['winner','team1','team2']])
# more than 1 column
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[0]
# to fetch 1st row
# Out:
# id                                      335982
# season                                 2007/08
# city                                 Bangalore
# date                                2008-04-18
# match_type                              League
# player_of_match                    BB McCullum
# venue                    M Chinnaswamy Stadium
# team1              Royal Challengers Bangalore
# team2                    Kolkata Knight Riders
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                            140.0
# target_runs                              223.0
# target_overs                              20.0
# super_over                                   N
# method                                     NaN
# umpire1                              Asad Rauf
# umpire2                            RE Koertzen
# ...

# %%
data.iloc[1:3]
# slicing
# Out:
#        id   season        city        date match_type player_of_match  \
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
#
#                                         venue             team1  \
# 1  Punjab Cricket Association Stadium, Mohali   Kings XI Punjab
# 2                            Feroz Shah Kotla  Delhi Daredevils
#
#                  team2          toss_winner toss_decision  \
# 1  Chennai Super Kings  Chennai Super Kings           bat
# 2     Rajasthan Royals     Rajasthan Royals           bat
#
#                 winner   result  result_margin  target_runs  target_overs  \
# 1  Chennai Super Kings     runs           33.0        241.0          20.0
# 2     Delhi Daredevils  wickets            9.0        130.0          20.0
#
#   super_over method    umpire1         umpire2
# 1          N    NaN  MR Benson      SL Shastri
# 2          N    NaN  Aleem Dar  GA Pratapkumar

# %%
data.iloc[1:11:2]
# Out:
#        id   season        city        date match_type player_of_match  \
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                team1  \
# 1  Punjab Cricket Association Stadium, Mohali      Kings XI Punjab
# 3                            Wankhede Stadium       Mumbai Indians
# 5                      Sawai Mansingh Stadium     Rajasthan Royals
# 7             MA Chidambaram Stadium, Chepauk  Chennai Super Kings
# 9  Punjab Cricket Association Stadium, Mohali      Kings XI Punjab
#
#                          team2          toss_winner toss_decision  \
# 1          Chennai Super Kings  Chennai Super Kings           bat
# ...

# %%
data.iloc[[1,3,7]]
# Out:
#        id   season        city        date match_type player_of_match  \
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
#
#                                         venue                team1  \
# 1  Punjab Cricket Association Stadium, Mohali      Kings XI Punjab
# 3                            Wankhede Stadium       Mumbai Indians
# 7             MA Chidambaram Stadium, Chepauk  Chennai Super Kings
#
#                          team2          toss_winner toss_decision  \
# 1          Chennai Super Kings  Chennai Super Kings           bat
# 3  Royal Challengers Bangalore       Mumbai Indians           bat
# 7               Mumbai Indians       Mumbai Indians         field
#
#                         winner   result  result_margin  target_runs  \
# 1          Chennai Super Kings     runs           33.0        241.0
# ...

# %% [markdown]
# **iloc can also fetch columns**

# %%
data.iloc[:,[7,8,11]]
# Out:
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                            winner
# 0           Kolkata Knight Riders
# 1             Chennai Super Kings
# 2                Delhi Daredevils
# 3     Royal Challengers Bangalore
# ...

# %%
data['city']=='Delhi'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1090    False
# 1091    False
# 1092    False
# 1093    False
# 1094    False
# Name: city, Length: 1095, dtype: bool

# %%
type(data['city']=='Delhi')
#  boolean series
# Out:
# pandas.core.series.Series

# %%
mask=data['city']=='Delhi'
data[mask]
#  dataframe having city Delhi only
# Out:
#            id   season   city        date match_type   player_of_match  \
# 2      335984  2007/08  Delhi  2008-04-19     League       MF Maharoof
# 16     335998  2007/08  Delhi  2008-04-30     League        GD McGrath
# 27     336009  2007/08  Delhi  2008-05-08     League          MS Dhoni
# 36     336020  2007/08  Delhi  2008-05-15     League          A Mishra
# 38     336022  2007/08  Delhi  2008-05-17     League  DPMD Jayawardene
# ...       ...      ...    ...         ...        ...               ...
# 1058  1426273     2024  Delhi  2024-04-20     League           TM Head
# 1063  1426278     2024  Delhi  2024-04-24     League           RR Pant
# 1066  1426281     2024  Delhi  2024-04-27     League   J Fraser-McGurk
# 1079  1426294     2024  Delhi  2024-05-07     League     Kuldeep Yadav
# 1086  1426302     2024  Delhi  2024-05-14     League          I Sharma
#
#                             venue                team1  \
# 2                Feroz Shah Kotla     Delhi Daredevils
# ...

# %%
data[mask].shape
# Out:
# (90, 20)

# %%
def city_match_count(city):
    mask=data['city']==city
    return data[mask].shape[0]

# %%
city_match_count('Delhi')
# Out:
# 90

# %%
mask1=data['city']=='Delhi'
mask2=data['match_type']>'League'
data[mask1 & mask2]
# Out:
#          id season   city        date   match_type player_of_match  \
# 394  598070   2013  Delhi  2013-05-21  Qualifier 1      MEK Hussey
# 575  981017   2016  Delhi  2016-05-27  Qualifier 2       DA Warner
#
#                 venue                team1                team2  \
# 394  Feroz Shah Kotla  Chennai Super Kings       Mumbai Indians
# 575  Feroz Shah Kotla        Gujarat Lions  Sunrisers Hyderabad
#
#              toss_winner toss_decision               winner   result  \
# 394  Chennai Super Kings           bat  Chennai Super Kings     runs
# 575  Sunrisers Hyderabad         field  Sunrisers Hyderabad  wickets
#
#      result_margin  target_runs  target_overs super_over method    umpire1  \
# 394           48.0        193.0          20.0          N    NaN   NJ Llong
# 575            4.0        163.0          20.0          N    NaN  M Erasmus
#
#        umpire2
# 394  RJ Tucker
# 575  CK Nandan

# %%
data[mask1 & mask2].shape[0]
# Out:
# 2

# %%
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %% [markdown]
# **Pandas Plot**

# %%
import matplotlib.pyplot as plt

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head().plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['result_margin'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
a=data['winner'].value_counts()
a
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
a.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Rajasthan Royals', 'Kings XI Punjab',
#        'Sunrisers Hyderabad', 'Delhi Daredevils', 'Delhi Capitals',
#        'Deccan Chargers', 'Gujarat Titans', 'Lucknow Super Giants',
#        'Punjab Kings', 'Gujarat Lions', 'Pune Warriors',
#        'Rising Pune Supergiant', 'Royal Challengers Bengaluru',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object', name='winner')

# %%
a.head().values
# Out:
# array([144, 138, 131, 116, 112])

# %%
a['Mumbai Indians']
# Out:
# 144

# %%
data['team1'].value_counts()+data['team2'].value_counts()
# Out:
# Chennai Super Kings            238
# Deccan Chargers                 75
# Delhi Capitals                  91
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  45
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          251
# Lucknow Super Giants            44
# Mumbai Indians                 261
# Pune Warriors                   46
# Punjab Kings                    56
# Rajasthan Royals               221
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    240
# Royal Challengers Bengaluru     15
# Sunrisers Hyderabad            182
# Name: count, dtype: int64

# %%
data['team1'].value_counts()['Mumbai Indians']+data['team2'].value_counts()['Mumbai Indians']
# Out:
# 261

# %%
(data['team1'].value_counts()+data['team2'].value_counts()).sort_values()
# Out:
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# Royal Challengers Bengaluru     15
# Rising Pune Supergiant          16
# Gujarat Lions                   30
# Lucknow Super Giants            44
# Gujarat Titans                  45
# Pune Warriors                   46
# Punjab Kings                    56
# Deccan Chargers                 75
# Delhi Capitals                  91
# Delhi Daredevils               161
# Sunrisers Hyderabad            182
# Kings XI Punjab                190
# Rajasthan Royals               221
# Chennai Super Kings            238
# Royal Challengers Bangalore    240
# Kolkata Knight Riders          251
# Mumbai Indians                 261
# Name: count, dtype: int64

# %%
(data['team1'].value_counts()+data['team2'].value_counts()).sort_values().tail()
# Out:
# Rajasthan Royals               221
# Chennai Super Kings            238
# Royal Challengers Bangalore    240
# Kolkata Knight Riders          251
# Mumbai Indians                 261
# Name: count, dtype: int64

# %%
(data['team1'].value_counts()+data['team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 261
# Kolkata Knight Riders          251
# Royal Challengers Bangalore    240
# Chennai Super Kings            238
# Rajasthan Royals               221
# Kings XI Punjab                190
# Sunrisers Hyderabad            182
# Delhi Daredevils               161
# Delhi Capitals                  91
# Deccan Chargers                 75
# Punjab Kings                    56
# Pune Warriors                   46
# Gujarat Titans                  45
# Lucknow Super Giants            44
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Royal Challengers Bengaluru     15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
data.sort_values('city',ascending=False)
# Out:
#            id   season           city        date   match_type  \
# 1039  1422134     2024  Visakhapatnam  2024-04-03       League
# 253    548311     2012  Visakhapatnam  2012-04-07       League
# 556    980979     2016  Visakhapatnam  2016-05-10       League
# 553    980973     2016  Visakhapatnam  2016-05-08       League
# 563    980993     2016  Visakhapatnam  2016-05-15       League
# ...       ...      ...            ...         ...          ...
# 807   1216535  2020/21            NaN  2020-10-31       League
# 809   1216530  2020/21            NaN  2020-11-01       League
# 811   1216495  2020/21            NaN  2020-11-03       League
# 812   1237177  2020/21            NaN  2020-11-05  Qualifier 1
# 815   1237181  2020/21            NaN  2020-11-10        Final
#
#      player_of_match                                              venue  \
# 1039       SP Narine  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# ...

# %%
data
#  changes are not permanent

# data.sort_values('city',ascending=False,inplace=True)
#  for permanent changes
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
data.sort_values(['city','date'])
# Out:
#           id   season       city        date   match_type player_of_match  \
# 398   729279     2014  Abu Dhabi  2014-04-16       League       JH Kallis
# 400   729283     2014  Abu Dhabi  2014-04-18       League      GJ Maxwell
# 401   729285     2014  Abu Dhabi  2014-04-18       League       AM Rahane
# 405   729293     2014  Abu Dhabi  2014-04-21       League        SK Raina
# 411   729305     2014  Abu Dhabi  2014-04-26       League        PV Tambe
# ..       ...      ...        ...         ...          ...             ...
# 807  1216535  2020/21        NaN  2020-10-31       League    Ishan Kishan
# 809  1216530  2020/21        NaN  2020-11-01       League      PJ Cummins
# 811  1216495  2020/21        NaN  2020-11-03       League        S Nadeem
# 812  1237177  2020/21        NaN  2020-11-05  Qualifier 1       JJ Bumrah
# 815  1237181  2020/21        NaN  2020-11-10        Final        TA Boult
#
#                                    venue                  team1  \
# ...

# %%
data.sort_values(['city','date'],ascending=[True,False])
# Out:
#           id season       city        date match_type player_of_match  \
# 870  1254088   2021  Abu Dhabi  2021-10-08     League    Ishan Kishan
# 867  1254095   2021  Abu Dhabi  2021-10-06     League   KS Williamson
# 861  1254089   2021  Abu Dhabi  2021-10-02     League      RD Gaikwad
# 857  1254099   2021  Abu Dhabi  2021-09-28     League      KA Pollard
# 853  1254098   2021  Abu Dhabi  2021-09-26     League       RA Jadeja
# ..       ...    ...        ...         ...        ...             ...
# 406   729295   2014        NaN  2014-04-22     League      GJ Maxwell
# 404   729291   2014        NaN  2014-04-20     League      GJ Maxwell
# 402   729287   2014        NaN  2014-04-19     League        PA Patel
# 403   729289   2014        NaN  2014-04-19     League       JP Duminy
# 399   729281   2014        NaN  2014-04-17     League       YS Chahal
#
#                                    venue                        team1  \
# ...

# %%
data.drop_duplicates(subset=['city'])
# Out:
#            id   season            city        date match_type  \
# 0      335982  2007/08       Bangalore  2008-04-18     League
# 1      335983  2007/08      Chandigarh  2008-04-19     League
# 2      335984  2007/08           Delhi  2008-04-19     League
# 3      335985  2007/08          Mumbai  2008-04-20     League
# 4      335986  2007/08         Kolkata  2008-04-20     League
# 5      335987  2007/08          Jaipur  2008-04-21     League
# 6      335988  2007/08       Hyderabad  2008-04-22     League
# 7      335989  2007/08         Chennai  2008-04-23     League
# 58     392181     2009       Cape Town  2009-04-18     League
# 62     392185     2009  Port Elizabeth  2009-04-20     League
# 63     392186     2009          Durban  2009-04-21     League
# 73     392198     2009       Centurion  2009-04-28     League
# 78     392203     2009     East London  2009-05-01     League
# 81     392206     2009    Johannesburg  2009-05-02     League
# ...

# %%
data.drop_duplicates(subset=['city']).shape
# Out:
# (37, 20)

# %%
data.drop_duplicates(subset=['city','season']).shape
#  work as 'and' operator i.e keeps only one row and deletes rest having same city and season both as that one row.
# Out:
# (165, 20)

# %%
new_data = data.drop_duplicates('season', keep='last')
new_data
# Out:
#            id   season          city        date match_type player_of_match  \
# 57     336040  2007/08        Mumbai  2008-06-01      Final       YK Pathan
# 114    392239     2009  Johannesburg  2009-05-24      Final        A Kumble
# 174    419165  2009/10        Mumbai  2010-04-25      Final        SK Raina
# 247    501271     2011       Chennai  2011-05-28      Final         M Vijay
# 321    548381     2012       Chennai  2012-05-27      Final        MS Bisla
# 397    598073     2013       Kolkata  2013-05-26      Final      KA Pollard
# 457    734049     2014     Bangalore  2014-06-01      Final       MK Pandey
# 516    829823     2015       Kolkata  2015-05-24      Final       RG Sharma
# 576    981019     2016     Bangalore  2016-05-29      Final     BCJ Cutting
# 635   1082650     2017     Hyderabad  2017-05-21      Final       KH Pandya
# 695   1136620     2018        Mumbai  2018-05-27      Final       SR Watson
# ...

# %%
new_data[['season','winner']]
# Out:
#        season                 winner
# 57    2007/08       Rajasthan Royals
# 114      2009        Deccan Chargers
# 174   2009/10    Chennai Super Kings
# 247      2011    Chennai Super Kings
# 321      2012  Kolkata Knight Riders
# 397      2013         Mumbai Indians
# 457      2014  Kolkata Knight Riders
# 516      2015         Mumbai Indians
# 576      2016    Sunrisers Hyderabad
# 635      2017         Mumbai Indians
# 695      2018    Chennai Super Kings
# 755      2019         Mumbai Indians
# 815   2020/21         Mumbai Indians
# 875      2021    Chennai Super Kings
# 949      2022         Gujarat Titans
# 1023     2023    Chennai Super Kings
# 1094     2024  Kolkata Knight Riders

# %%
data
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
data.rename(columns={'city':'place','date':'dom'})
# Out:
#            id   season       place         dom   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
data
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
data.set_index(['id','season'])
# Out:
#                        city        date   match_type  player_of_match  \
# id      season
# 335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...                     ...         ...          ...              ...
# 1426307 2024      Hyderabad  2024-05-19       League  Abhishek Sharma
# 1426309 2024      Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1426310 2024      Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1426311 2024        Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1426312 2024        Chennai  2024-05-26        Final         MA Starc
#
#                                                              venue  \
# id      season
# ...

# %%
data.reset_index()
# Out:
#       index       id   season        city        date   match_type  \
# 0         0   335982  2007/08   Bangalore  2008-04-18       League
# 1         1   335983  2007/08  Chandigarh  2008-04-19       League
# 2         2   335984  2007/08       Delhi  2008-04-19       League
# 3         3   335985  2007/08      Mumbai  2008-04-20       League
# 4         4   335986  2007/08     Kolkata  2008-04-20       League
# ...     ...      ...      ...         ...         ...          ...
# 1090   1090  1426307     2024   Hyderabad  2024-05-19       League
# 1091   1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1
# 1092   1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator
# 1093   1093  1426311     2024     Chennai  2024-05-24  Qualifier 2
# 1094   1094  1426312     2024     Chennai  2024-05-26        Final
#
#       player_of_match                                              venue  \
# 0         BB McCullum                              M Chinnaswamy Stadium
# ...

# %%
data['winner'].value_counts(ascending=True)
# Out:
# winner
# Rising Pune Supergiants          5
# Kochi Tuskers Kerala             6
# Royal Challengers Bengaluru      7
# Rising Pune Supergiant          10
# Pune Warriors                   12
# Gujarat Lions                   13
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Titans                  28
# Deccan Chargers                 29
# Delhi Capitals                  48
# Delhi Daredevils                67
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Rajasthan Royals               112
# Royal Challengers Bangalore    116
# Kolkata Knight Riders          131
# Chennai Super Kings            138
# Mumbai Indians                 144
# Name: count, dtype: int64

# %%
data['winner'].value_counts().reset_index()
# Out:
#                          winner  count
# 0                Mumbai Indians    144
# 1           Chennai Super Kings    138
# 2         Kolkata Knight Riders    131
# 3   Royal Challengers Bangalore    116
# 4              Rajasthan Royals    112
# 5               Kings XI Punjab     88
# 6           Sunrisers Hyderabad     88
# 7              Delhi Daredevils     67
# 8                Delhi Capitals     48
# 9               Deccan Chargers     29
# 10               Gujarat Titans     28
# 11         Lucknow Super Giants     24
# 12                 Punjab Kings     24
# 13                Gujarat Lions     13
# 14                Pune Warriors     12
# 15       Rising Pune Supergiant     10
# 16  Royal Challengers Bengaluru      7
# 17         Kochi Tuskers Kerala      6
# 18      Rising Pune Supergiants      5

# %%
new=data.dropna()
new
# deletes rows having atleast one col with value=Nan
# Out:
#            id   season           city        date  match_type  \
# 38     336022  2007/08          Delhi  2008-05-17      League
# 41     336025  2007/08        Kolkata  2008-05-18      League
# 60     392183     2009      Cape Town  2009-04-19      League
# 63     392186     2009         Durban  2009-04-21      League
# 89     392214     2009      Centurion  2009-05-07      League
# 192    501215     2011          Kochi  2011-04-18      League
# 221    501245     2011        Kolkata  2011-05-07      League
# 231    501255     2011      Bangalore  2011-05-14      League
# 429    733993     2014          Delhi  2014-05-10      League
# 476    829743     2015  Visakhapatnam  2015-04-22      League
# 508    829807     2015      Hyderabad  2015-05-15      League
# 538    980943     2016      Hyderabad  2016-04-26      League
# 561    980989     2016        Kolkata  2016-05-14      League
# 565    980997     2016  Visakhapatnam  2016-05-17      League
# ...

# %%
new.shape
# Out:
# (21, 20)

# %%
new2=data.dropna(how='all')
new2
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
new2.shape
# i.e there is no row in the dataset having value in all cols=NaN
# Out:
# (1095, 20)

# %%
data.shape
# Out:
# (1095, 20)

# %%
new3=data.dropna(axis=1)
new3
# col -wise
# Out:
#            id   season        date   match_type  \
# 0      335982  2007/08  2008-04-18       League
# 1      335983  2007/08  2008-04-19       League
# 2      335984  2007/08  2008-04-19       League
# 3      335985  2007/08  2008-04-20       League
# 4      335986  2007/08  2008-04-20       League
# ...       ...      ...         ...          ...
# 1090  1426307     2024  2024-05-19       League
# 1091  1426309     2024  2024-05-21  Qualifier 1
# 1092  1426310     2024  2024-05-22   Eliminator
# 1093  1426311     2024  2024-05-24  Qualifier 2
# 1094  1426312     2024  2024-05-26        Final
#
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...

# %%
new3.shape
# Out:
# (1095, 13)

# %%
new4=data.dropna(axis=1,how='all')
new4
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
new4.shape
# Out:
# (1095, 20)

# %%
new5=data.dropna(subset=['city','method'])
new5
# Out:
#            id   season           city        date  match_type  \
# 38     336022  2007/08          Delhi  2008-05-17      League
# 41     336025  2007/08        Kolkata  2008-05-18      League
# 60     392183     2009      Cape Town  2009-04-19      League
# 63     392186     2009         Durban  2009-04-21      League
# 89     392214     2009      Centurion  2009-05-07      League
# 192    501215     2011          Kochi  2011-04-18      League
# 221    501245     2011        Kolkata  2011-05-07      League
# 231    501255     2011      Bangalore  2011-05-14      League
# 429    733993     2014          Delhi  2014-05-10      League
# 476    829743     2015  Visakhapatnam  2015-04-22      League
# 508    829807     2015      Hyderabad  2015-05-15      League
# 538    980943     2016      Hyderabad  2016-04-26      League
# 561    980989     2016        Kolkata  2016-05-14      League
# 565    980997     2016  Visakhapatnam  2016-05-17      League
# ...

# %%
new5.shape
# Out:
# (21, 20)

# %%
data
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
data.fillna(0)
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
data['method'].fillna("0",inplace=True)

# %%
data
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
data.shape
# Out:
# (1095, 20)
